# %% [markdown]
# # Importar CSV

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("train.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %% [markdown]
# # Arreglando problemas de NaNs.

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
dfclean = df.drop("PoolQC", axis=1)
#dfclean = dfclean.drop("MiscFeature", axis=1)
dfclean = dfclean.drop("Alley", axis=1)
dfclean = dfclean.drop("MiscFeature", axis=1)

# %%
dfclean = dfclean.drop("Fence", axis=1)

# %%
dfclean
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
a= dfclean.isnull().sum().sort_values(ascending=False)

# Filter out the columns that have missing values
missing_values23 = a[a > 0]

missing_values23
# Out:
# FireplaceQu     530
# BsmtExposure     25
# BsmtFinType2     25
# BsmtQual         24
# BsmtCond         24
# BsmtFinType1     24
# Electrical        1
# dtype: int64

# %%
import pandas as pd

# Supongamos que dfclean es tu DataFrame
# Identificar columnas con NaN y que son de tipo numérico
numeric_columns_with_nan = dfclean.select_dtypes(include=['number']).columns[dfclean.select_dtypes(include=['number']).isna().any()]

# Mostrar las columnas identificadas
print("Columnas con NaN y tipo numérico:")
print(numeric_columns_with_nan)
# Out:
# Columnas con NaN y tipo numérico:
# Index(['LotFrontage', 'MasVnrArea', 'GarageYrBlt'], dtype='object')

# %%
import pandas as pd

# Supongamos que dfclean es tu DataFrame
# Lista de columnas
columns_to_check = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# Eliminar filas que contienen NaN en alguna de las columnas especificadas
dfclean = dfclean.dropna(subset=columns_to_check, how='any')

# %%
dfclean.to_excel('ppp.xlsx', index=False)

# %%
import pandas as pd



# Iterar sobre cada columna del DataFrame
for columna in dfclean.columns:
    tipos_de_valores = dfclean[columna].value_counts()
    cantidad_tipos_valores = len(tipos_de_valores)

    print(f"Columna: {columna}")
    print(f"Cantidad de tipos de valores: {cantidad_tipos_valores}")
    print("Tipos de valores y sus conteos:")
    print(tipos_de_valores)
    print("\n")

# %% [markdown]
# # Zona de graficacicon

# %%
# Calcula la matriz de correlación
correlation_matrix = df.corr()

# Visualiza la  matriz de correlación utilizando seaborn
plt.figure(figsize=(20, 16))  # Tamaño de la figura
sns.heatmap(correlation_matrix, annot=False, linewidths=0.5)
plt.title("Matriz de Correlación")
plt.show()
# Out:
# <ipython-input-15-08c6f995ce90>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Iterar sobre cada columna del DataFrame
for columna in dfclean.columns:
    tipos_de_valores = dfclean[columna].value_counts()

    # Graficar los conteos
    tipos_de_valores.plot(kind='bar', title=f'Conteos de valores para {columna}')
    plt.xlabel('Valores')
    plt.ylabel('Conteos')
    plt.show()

# %%
import matplotlib.pyplot as plt

# Supongamos que dfclean es tu DataFrame
columns_to_plot = ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageCars', 'GarageArea']

# Configurar el tamaño del gráfico
plt.figure(figsize=(15, 10))

# Crear subgráficos para cada columna
for i, column in enumerate(columns_to_plot, 1):
    plt.subplot(3, 3, i)
    plt.hist(dfclean[column].dropna(), bins=30, edgecolor='black')  # Eliminar NaN y configurar los bordes del histograma
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')

# Ajustar el diseño de los subgráficos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # One hot Encoding

# %%
dfclean
# Out:
#           Id  MSSubClass MSZoning LotFrontage  LotArea Street LotShape  \
# 0        1.0        60.0       RL        65.0   8450.0   Pave      Reg
# 1        2.0        20.0       RL        80.0   9600.0   Pave      Reg
# 2        3.0        60.0       RL        68.0  11250.0   Pave      IR1
# 3        4.0        70.0       RL        60.0   9550.0   Pave      IR1
# 4        5.0        60.0       RL        84.0  14260.0   Pave      IR1
# ...      ...         ...      ...         ...      ...    ...      ...
# 1455  1456.0        60.0       RL        62.0   7917.0   Pave      Reg
# 1456  1457.0        20.0       RL        85.0  13175.0   Pave      Reg
# 1457  1458.0        70.0       RL        66.0   9042.0   Pave      Reg
# 1458  1459.0        20.0       RL        68.0   9717.0   Pave      Reg
# 1459  1460.0        20.0       RL        75.0   9937.0   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
# Use the fitted model to transform the feature set
X = dfclean.drop(columns=['SalePrice'])
y = dfclean['SalePrice']

# %%
#Remplazar los NaN por No tienen
# Lista de columnas con NaNs
columns_with_nan = missing_values23.index

# Reemplazar NaNs por "No" en las columnas con NaNs
dfclean[columns_with_nan] = dfclean[columns_with_nan].fillna("missing")
# Out:
# <ipython-input-78-dbe75fc2b16f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfclean[columns_with_nan] = dfclean[columns_with_nan].fillna("missing")

# %%
dfclean.dtypes
# Out:
# Id               float64
# MSSubClass       float64
# MSZoning          object
# LotFrontage       object
# LotArea          float64
#                   ...
# MoSold           float64
# YrSold           float64
# SaleType          object
# SaleCondition     object
# SalePrice        float64
# Length: 77, dtype: object

# %%
from sklearn.impute import SimpleImputer

# Supongamos que dfclean es tu DataFrame
columns_to_impute = ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageCars', 'GarageArea']

# Crear un SimpleImputer con la estrategia de la mediana
imputer = SimpleImputer(strategy='median')

# Ajustar e imputar los valores en las columnas especificadas
dfclean[columns_to_impute] = imputer.fit_transform(dfclean[columns_to_impute])
# Out:
# <ipython-input-133-9c00141a5fd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfclean[columns_to_impute] = imputer.fit_transform(dfclean[columns_to_impute])

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier

# Identify the categorical columns
categorical_columns = dfclean.select_dtypes(include=['object']).columns

# Apply one-hot encoding to the categorical columns
preprocessor = make_column_transformer(
    (OneHotEncoder(handle_unknown='ignore'), categorical_columns),
    remainder='passthrough'
)

# Define the target variable
y = dfclean['SalePrice']

# Define the feature set
X = dfclean.drop(columns=['SalePrice'])

# Create a pipeline that first one-hot encodes the data and then applies RFE
model = make_pipeline(
    preprocessor,
    RFE(estimator=LinearRegression(), n_features_to_select=20)
)

model.fit(X, y)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2n...Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object'))])),
#                 ('rfe',
# ...

# %% [markdown]
# # Evaluacion del modelo

# %%
# Load the new test dataset
test_df = pd.read_csv('test.csv')

x_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
a= x_test.isnull().sum().sort_values(ascending=False)

# Filter out the columns that have missing values
missing_values23 = a[a > 0]

missing_values23
# Out:
# FireplaceQu     571
# BsmtCond         32
# BsmtQual         31
# BsmtExposure     31
# BsmtFinType2     29
# BsmtFinType1     29
# MSZoning          3
# Functional        2
# BsmtHalfBath      2
# BsmtFullBath      2
# Utilities         1
# TotalBsmtSF       1
# MasVnrType        1
# BsmtFinSF2        1
# BsmtFinSF1        1
# SaleType          1
# KitchenQual       1
# BsmtUnfSF         1
# dtype: int64

# %%
x_test = test_df.drop("PoolQC", axis=1)
#dfclean = dfclean.drop("MiscFeature", axis=1)
x_test = x_test.drop("Alley", axis=1)
x_test = x_test.drop("MiscFeature", axis=1)
x_test = x_test.drop("Fence", axis=1)

# %%
# Identificar columnas con NaN y que son de tipo numérico
numeric_columns_with_nan = x_test.select_dtypes(include=['number']).columns[x_test.select_dtypes(include=['number']).isna().any()]

# Mostrar las columnas identificadas
print("Columnas con NaN y tipo numérico:")
print(numeric_columns_with_nan)
# Out:
# Columnas con NaN y tipo numérico:
# Index(['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt',
#        'GarageCars', 'GarageArea'],
#       dtype='object')

# %%
import pandas as pd

# Lista de columnas
columns_to_check = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# Eliminar filas que contienen NaN en alguna de las columnas especificadas
x_test = x_test.dropna(subset=columns_to_check, how='any')

# %%
from sklearn.impute import SimpleImputer

# Supongamos que dfclean es tu DataFrame
columns_to_impute = ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageCars', 'GarageArea']

# Crear un SimpleImputer con la estrategia de la mediana
imputer = SimpleImputer(strategy='median')

# Ajustar e imputar los valores en las columnas especificadas
x_test[columns_to_impute] = imputer.fit_transform(x_test[columns_to_impute])
# Out:
# <ipython-input-142-308e3eb5a6eb>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[columns_to_impute] = imputer.fit_transform(x_test[columns_to_impute])

# %%
#Remplazar los NaN por No tienen
# Lista de columnas con NaNs
columns_with_nan = missing_values23.index

# Reemplazar NaNs por "No" en las columnas con NaNs
x_test[columns_with_nan] = x_test[columns_with_nan].fillna("missing")

# %%
x_test.to_excel('pp1p.xlsx', index=False)

# %%
# Identify the categorical columns
categorical_columns = x_test.select_dtypes(include=['object']).columns

# Apply one-hot encoding to the categorical columns
preprocessor1 = make_column_transformer(
    (OneHotEncoder(handle_unknown='ignore'), categorical_columns),
    remainder='passthrough'
)



# Use the RFE model to transform the imputed test feature set
test_X_transformed = model.transform(x_test)

test_y_pred = model.predict(x_test)

# Create a DataFrame with the IDs and the predicted prices
predictions_df = pd.DataFrame({
    'Id': x_test['Id'],
    'SalePrice': test_y_pred
})

predictions_df.head()
# Out:
#      Id      SalePrice
# 0  1461  126074.584320
# 1  1462  126074.584320
# 2  1463  179642.010486
# 3  1464  179642.010486
# 4  1465  255963.707771
